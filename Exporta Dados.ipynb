# %% [markdown]
# # Exporta dados do CNES PF para arquivo .parquet
# Esse notebook exporta os dados do CNES.PF do Dremio para um arquivo.parquet

# %% [markdown]
# ## Carregar bibliotecas

# %%
# Reload automático no Jupyter Notebook
# %reload_ext autoreload
# %autoreload 2

import warnings
from dados import *

# %% [markdown]
# ## Configurar bibliotecas

# %%
# Remover limite de exibição de linhas e colunas do pandas
pd.set_option('max_rows', 9999)
pd.set_option('max_columns', 9999)

# Evitar notações científicas no pandas
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Evitar warnings sobre perfomance no pandas
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %% [markdown]
# ## Obter dados

# %%
df = obter_dados('profissionais.sql')
df.head()

# %%
df.to_parquet('dados/profissionais_meta5.parquet')
